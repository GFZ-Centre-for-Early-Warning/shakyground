# %%
# %load_ext autoreload
# %autoreload 2
import warnings; warnings.filterwarnings("ignore")
import pandas as pd
#import lxml.etree as le
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import quakeml
import shakeml
import service
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#read example event from a local xml file
with open('sample_event.xml','r') as fp:
    sample_event_xml = fp.read()
#sample_event_xml

# %%
shakemap = service.event_shakemap(sample_event_xml,imt = ["PGA","SA(0.3)"],pgamin=0.1)
quakemap = shakeml.shakemap2quakemap(shakemap)
sm = quakemap.shakemap

# %%
sm.head()
# Out:
#          LON        LAT       PGA    STDPGA   SA(0.3)  STDSA(0.3)
# 0 -74.866667 -24.891667  0.043584  0.736259  0.038687    0.775375
# 1 -74.858333 -24.891667  0.043680  0.736259  0.038800    0.775375
# 2 -74.850000 -24.891667  0.043775  0.736259  0.038914    0.775375
# 3 -74.841667 -24.891667  0.043872  0.736259  0.039028    0.775375
# 4 -74.833333 -24.891667  0.043968  0.736259  0.039142    0.775375

# %%
plt.figure(figsize=(10,9))
curim = "SA(0.3)"
plt.scatter(sm["LON"], sm["LAT"], c=sm[curim], edgecolor="None", norm=LogNorm(vmin=0.01, vmax=0.5))
plt.colorbar(label=curim)
plt.axis('equal')
# Out:
# (-76.39133064519463,
#  -65.51700268820537,
#  -35.79049515578678,
#  -20.551171510913218)
